# %%
# creating list of the domain attributes
domain_attributes = []
print("initailly the list is empty")
print(domain_attributes)

domain_attributes_set={"Genre","Language"}
domain_attributes.append("User")
print("After using append command")
print(domain_attributes)

domain_attributes.insert(2,"Payment")
print("After using insert command")
print(domain_attributes)

domain_attributes2=["Admin","Reviews"]
domain_attributes.extend(domain_attributes2)
print("After embedding a list using extend command")
print(domain_attributes)

domain_attributes.insert(4,domain_attributes_set)
print("After inserting set  using insert command")
print(domain_attributes)


# creating a list using numeric 
# part1
print("\n creating a list using numeric ")
def swapList(newList):
    size = len(newList)
     
    # Swapping
    temp = newList[0]
    newList[0] = newList[size - 1]
    newList[size - 1] = temp
     
    return newList
newList = [12, 35, 9, 56, 24]
print(newList) 
print("List after swaping first and last index value")
print(swapList(newList))


# part2. Write a program to find the sum of the digits in a list.
sum = 0
for i in newList:
    sum += i
print(f"Sum of the digits in the list is:{sum}")


# part3. Write a program to find the smallest element in a list.
def find_smallest_element(num_list):
    smallest = num_list[0]
    for num in num_list:
        if num < smallest:
            smallest = num
    return smallest

print("Original list of numbers:", newList)

smallest_element = find_smallest_element(newList)

print("Smallest element in the list:", smallest_element)
# Out:
# initailly the list is empty
# []
# After using append command
# ['User']
# After using insert command
# ['User', 'Payment']
# After embedding a list using extend command
# ['User', 'Payment', 'Admin', 'Reviews']
# After inserting set  using insert command
# ['User', 'Payment', 'Admin', 'Reviews', {'Language', 'Genre'}]
#
#  creating a list using numeric
# [12, 35, 9, 56, 24]
# List after swaping first and last index value
# [24, 35, 9, 56, 12]
# Sum of the digits in the list is:136

# %%
# 1. Sort the dictionaries in ascending order based on the Key of the dictionary.
print("Part 1 . Sort the dictionaries in ascending order based on the Key of the dictionary. \n")
def sortDict_keys(dictionary):
    sorted_keys = sorted(dictionary.keys())
    return sorted_keys

my_dict = {'b': 13, 'a': 11, 'd':24, 'c': 36}

sorted_keys = sortDict_keys(my_dict)

for key in sorted_keys:
    print(key, my_dict[key])

# 2. Create the dictionary with Numeric as Value in Key – Value pair and find the sum of all the values in the Dictionary
print(" Part 2.Create the dictionary with Numeric as Value in Key – Value pair and find the sum of all the values in the Dictionary \n")
def sum_of_values(dictionary):
    total_sum = 0
    for value in dictionary.values():
        total_sum += value
    return total_sum

# Create a dictionary with numeric values
print("Part 3.Create a dictionary with numeric values \n")
numeric_dict = {
    "value1": 23,
    "value2": 98,
    "value3": 30,
    "value4": 24,
    "value5": 99,
}

print("Original dictionary:", numeric_dict)

total_value_sum = sum_of_values(numeric_dict)


# 3.Write a Python code to demonstrate the sorting in descending order of values with lambda function.
print("3.Write a Python code to demonstrate the sorting in descending order of values with lambda function.")
print("Sum of all values in the dictionary:", total_value_sum)
my_dict = {'user_id': 5, 'payment_id': 10, 'genre_id': 3, 'lang_id': 8, 'speaker_id': 2}

# Sorting the dictionary in descending order of values using a lambda function
sorted_dict = dict(sorted(my_dict.items(), key=lambda item: item[1], reverse=True))

for key, value in sorted_dict.items():
    print(f'{key}: {value}')
# Out:
# Part 1 . Sort the dictionaries in ascending order based on the Key of the dictionary.
#
# a 11
# b 13
# c 36
# d 24
#  Part 2.Create the dictionary with Numeric as Value in Key – Value pair and find the sum of all the values in the Dictionary
#
# Part 3.Create a dictionary with numeric values
#
# Original dictionary: {'value1': 23, 'value2': 98, 'value3': 30, 'value4': 24, 'value5': 99}
# Sum of all values in the dictionary: 274
# payment_id: 10
# lang_id: 8
# user_id: 5
# genre_id: 3
# speaker_id: 2
